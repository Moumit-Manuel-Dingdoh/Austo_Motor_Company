# %% [markdown]
# Austo Motor Company is a leading car manufacturer specializing in SUV, Sedan, and Hatchback models. In its recent board meeting, concerns were raised by the members on the efficiency of the marketing campaign currently being used. The board decides to rope in an analytics professional to improve the existing campaign.

# %% [markdown]
# # Data Overview

# %% [markdown]
# ###  Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the data

# %%
df_austo_motor = pd.read_csv('austo_automobile+%282%29+%281%29.csv')
df_austo_motor
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53   Femal   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %% [markdown]
# ### Check the structure of the data
# ### Check the types of the data

# %%
df_austo_motor.head()   # to view top 5 records of the dataset
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
df_austo_motor.tail()   # to view bottom 5 records of the dataset
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1576   22   Male   Salaried         Single  Graduate                 2
# 1577   22   Male   Business        Married  Graduate                 4
# 1578   22   Male   Business         Single  Graduate                 2
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1576            No        Yes              No   33300             0.0
# 1577            No         No              No   32000             NaN
# 1578            No        Yes              No   32900             0.0
# 1579           Yes        Yes              No   32200             NaN
# 1580            No         No              No   31600             0.0
#
#       Total_salary  Price       Make
# 1576         33300  27000  Hatchback
# 1577         32000  31000  Hatchback
# ...

# %%
df_austo_motor.columns   # to view the column names of the dataset
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %%
df_austo_motor.shape   # to view the total number of rows and columns in the dataset
# Out:
# (1581, 14)

# %%
df_austo_motor.dtypes   # to view the data types of the columns
# Out:
# Age                   int64
# Gender               object
# Profession           object
# Marital_status       object
# Education            object
# No_of_Dependents      int64
# Personal_loan        object
# House_loan           object
# Partner_working      object
# Salary                int64
# Partner_salary      float64
# Total_salary          int64
# Price                 int64
# Make                 object
# dtype: object

# %% [markdown]
# ### Check for and treat (if needed) missing values

# %%
df_austo_motor.isnull().sum()   # checking for missing values
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
# Replacing missing Gender values with mode() function

df_austo_motor['Gender'].fillna(df_austo_motor['Gender'].mode()[0], inplace=True)

# %%
# Replacing missing Partner_salary values with median() function

df_austo_motor['Partner_salary'].fillna(df_austo_motor['Partner_salary'].median(), inplace=True)

# %%
df_austo_motor.isnull().sum()   # checking the missing values in the dataset once again
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %% [markdown]
# ### Check the statistical summary

# %%
df_austo_motor.info()   # to view the informations of each columns in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
df_austo_motor.describe()   # to view the statistical descriptive of the numerical variables in the dataset
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1581.000000
# mean     31.922201          2.457938  60392.220114    20585.895003
# std       8.425978          0.943483  14674.825044    18952.938643
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    25600.000000
# 75%      38.000000          3.000000  71800.000000    38000.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
df_austo_motor.describe(include='all').T   # to view the statistical descriptive of all columns
# Out:
#                    count unique            top  freq          mean  \
# Age               1581.0    NaN            NaN   NaN     31.922201
# Gender              1581      4           Male  1252           NaN
# Profession          1581      2       Salaried   896           NaN
# Marital_status      1581      2        Married  1443           NaN
# Education           1581      2  Post Graduate   985           NaN
# No_of_Dependents  1581.0    NaN            NaN   NaN      2.457938
# Personal_loan       1581      2            Yes   792           NaN
# House_loan          1581      2             No  1054           NaN
# Partner_working     1581      2            Yes   868           NaN
# Salary            1581.0    NaN            NaN   NaN  60392.220114
# Partner_salary    1581.0    NaN            NaN   NaN  20585.895003
# Total_salary      1581.0    NaN            NaN   NaN  79625.996205
# Price             1581.0    NaN            NaN   NaN   35597.72296
# ...

# %% [markdown]
# ### Check for and treat (if needed) data irregularities

# %%
df_austo_motor.nunique()   # to view the unique number of values in each columns in the dataset
# Out:
# Age                  33
# Gender                4
# Profession            2
# Marital_status        2
# Education             2
# No_of_Dependents      5
# Personal_loan         2
# House_loan            2
# Partner_working       2
# Salary              538
# Partner_salary      149
# Total_salary        754
# Price                53
# Make                  3
# dtype: int64

# %%
print("The unique values in the Gender column were: ", df_austo_motor['Gender'].unique())   # to view the unique values in the column Gender
# Out:
# The unique values in the Gender column were:  ['Male' 'Femal' 'Female' 'Femle']

# %%
# Treating data irregularities 

df_austo_motor['Gender'].replace({'Femal': 'Female', 'Femle': 'Female'}, inplace=True)

# %%
print(df_austo_motor['Gender'].unique())   # to view the unique values in the column Gender once again
print(df_austo_motor['Profession'].unique())
print(df_austo_motor['Marital_status'].unique())
print(df_austo_motor['Education'].unique())
print(df_austo_motor['No_of_Dependents'].unique())
print(df_austo_motor['House_loan'].unique())
print(df_austo_motor['Partner_working'].unique())
print(df_austo_motor['Make'].unique())
# Out:
# ['Male' 'Female']
# ['Business' 'Salaried']
# ['Married' 'Single']
# ['Post Graduate' 'Graduate']
# [4 3 2 1 0]
# ['No' 'Yes']
# ['Yes' 'No']
# ['SUV' 'Sedan' 'Hatchback']

# %%
df_austo_motor.duplicated()   # to view if any duplicate columns are in the dataset
print("Any duplicate columns in the dataset: ", df_austo_motor.duplicated().sum())
# Out:
# Any duplicate columns in the dataset:  0

# %% [markdown]
# ### Observations and Insights

# %% [markdown]
#  1. The Austo Motor Company dataset contains 1581 rows and 14 columns.
#  2. The Numerical columns were 'Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary', 'Price'.
#  3. The catagorical columns were 'Gender', 'Profession', 'Marital_status', 'Education', 'Personal_loan', 'House_loan', 'Partner_working', 'Make'.
#  4. Missing values were observed in Gender and Partner_salary. columns. The treatment of the missing values were done by replacing with mode() with Gender and median() with Partner_salary.
#  5. There were no duplicate values present in the dataset.
#  6. Data irregularities were present in Gender columns. The treatment was done by replacing with the correct value.
#  7. The dataset was structured, handled all the missing values of the dataset and corrected the irregularities of the data to perform the analysis in the next further step.

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Explore all the variables (categorical and numerical) in the data
# ### Numerical data

# %%
df_austo_motor.select_dtypes(exclude=object).columns   # it will show the columns having numerical datatypes
# Out:
# Index(['Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary',
#        'Price'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))

sns.histplot(data=df_austo_motor,x='Age', kde=True, ax=ax[0])
sns.boxplot(data=df_austo_motor,x='Age', ax=ax[1])

ax[0].set_title('Histogram with KDE for Age')
ax[1].set_title('Boxplot for Age')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.histplot(data=df_austo_motor,x='No_of_Dependents', kde=True, ax=ax[0])
sns.boxplot(data=df_austo_motor,x='No_of_Dependents', ax=ax[1])

ax[0].set_title('Histogram with KDE for No_of_Dependents')
ax[1].set_title('Boxplot for No_of_Dependents')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.histplot(data=df_austo_motor,x='Salary', kde=True, ax=ax[0])
sns.boxplot(data=df_austo_motor,x='Salary', ax=ax[1])

ax[0].set_title('Histogram with KDE for Salary')
ax[1].set_title('Boxplot for Salary')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.histplot(data=df_austo_motor,x='Partner_salary', kde=True, ax=ax[0])
sns.boxplot(data=df_austo_motor,x='Partner_salary', ax=ax[1])

ax[0].set_title('Histogram with KDE for Partner_salary')
ax[1].set_title('Boxplot for Partner_salary')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.histplot(data=df_austo_motor,x='Total_salary', kde=True, ax=ax[0])
sns.boxplot(data=df_austo_motor,x='Total_salary', ax=ax[1])

ax[0].set_title('Histogram with KDE for Total_salary')
ax[1].set_title('Boxplot for Total_salary')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.histplot(data=df_austo_motor,x='Price', kde=True,ax=ax[0])
sns.boxplot(data=df_austo_motor,x='Price', ax=ax[1])

ax[0].set_title('Histogram with KDE for Price')
ax[1].set_title('Boxplot for Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Catagorical data

# %%
df_austo_motor.select_dtypes(include=object).columns
# Out:
# Index(['Gender', 'Profession', 'Marital_status', 'Education', 'Personal_loan',
#        'House_loan', 'Partner_working', 'Make'],
#       dtype='object')

# %%
fig, ax = plt.subplots(2,4, figsize = (12,6))

sns.countplot(data=df_austo_motor,x='Gender', ax = ax[0,0])
sns.countplot(data=df_austo_motor,x='Profession', ax = ax[0,1])
sns.countplot(data=df_austo_motor,x='Marital_status', ax = ax[0,2])
sns.countplot(data=df_austo_motor,x='Education', ax = ax[0,3])
sns.countplot(data=df_austo_motor,x='Personal_loan', ax = ax[1,0])
sns.countplot(data=df_austo_motor,x='House_loan', ax = ax[1,1])
sns.countplot(data=df_austo_motor,x='Partner_working', ax = ax[1,2])
sns.countplot(data=df_austo_motor,x='Make', ax = ax[1,3])

plt.tight_layout()
plt.show()

# %%
# outlier checking

num_cols = ['Age','No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary','Price']

Q1 = df_austo_motor[num_cols].quantile(0.25)
Q3 = df_austo_motor[num_cols].quantile(0.75)

IQR = Q3-Q1

low_whisker = Q1 - 1.5*IQR
up_whisker = Q3 + 1.5*IQR

((df_austo_motor[num_cols] < low_whisker) | (df_austo_motor[num_cols] > up_whisker)).sum()/df_austo_motor.shape[0]*100
# Out:
# Age                 0.000000
# No_of_Dependents    1.265022
# Salary              0.000000
# Partner_salary      0.000000
# Total_salary        1.707780
# Price               0.000000
# dtype: float64

# %%
# Outliers treatment using Clipping/Capping approach

def outliers_treatment(df, col):
    Q1 = df[col].quantile()
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3-Q1

    low_whisker = Q1 - 1.5*IQR
    up_whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], low_whisker, up_whisker)
    return df

# %%
df_austo_motor = outliers_treatment(df_austo_motor,'No_of_Dependents')
df_austo_motor = outliers_treatment(df_austo_motor,'Total_salary')

fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.boxplot(data=df_austo_motor,x='No_of_Dependents', ax=ax[0])
sns.boxplot(data=df_austo_motor,x='Total_salary', ax=ax[1])

ax[0].set_title('Boxplot for No_of_Dependents')
ax[1].set_title('Boxplot for Total_salary')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations and insights

# %% [markdown]
# 1. The Age variable is right-skewed without any outliers
# 2. The No_of_Dependents is normal distribution with outliers present on lower whiskers
# 3. The distribution for Partner_salary, Salary, Price and Total_salary with a right-skewed without having outliers but, Total_salary is having outliers at the upper whiskers.
# 4. In catagorical variables, Male has more in count than female and the Personal_loan (Yes/No) are almost equally distributed.
# 5. The Salaried professions who has completed Post-Graduations, got Married and their Partners are working, and having House_loan were significantly higher.
# 6. The automobile company manufacture more number of Sedan in compare with SUV and Hatchback.
# 7. The outliers treatment was done using Clipping/Capping approach to analyse the whole dataset in the next steps to ensure more accurate data analysis.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### Explore the relationship between all numerical variables

# %%
sns.pairplot(df_austo_motor, diag_kind="kde")
plt.show()

# %% [markdown]
# ### Explore the correlation between all numerical variables

# %%
df_austo_motor.corr()   # to check the corelation of each numerical variables
# Out:
#                        Age  No_of_Dependents    Salary  Partner_salary  \
# Age               1.000000         -0.194020  0.616899        0.121187
# No_of_Dependents -0.194020          1.000000 -0.032646        0.117950
# Salary            0.616899         -0.032646  1.000000        0.065348
# Partner_salary    0.121187          0.117950  0.065348        1.000000
# Total_salary      0.452844          0.083573  0.638625        0.765147
# Price             0.797831         -0.141375  0.409920        0.161136
#
#                   Total_salary     Price
# Age                   0.452844  0.797831
# No_of_Dependents      0.083573 -0.141375
# Salary                0.638625  0.409920
# Partner_salary        0.765147  0.161136
# Total_salary          1.000000  0.359651
# Price                 0.359651  1.000000

# %%
sns.heatmap(data = df_austo_motor.corr(), annot=True)   # to view the corelation between variables in visualization manner
plt.show()

# %% [markdown]
# ### Explore the relationship between categorical vs numerical variables

# %%
fig, ax = plt.subplots(2,4, figsize = (12,6))

sns.barplot(df_austo_motor, x="Gender", y="Salary", ax = ax[0,0])
sns.barplot(df_austo_motor, x="Gender", y="Age", ax = ax[0,1])
sns.barplot(df_austo_motor, x="Make", y="Price", ax = ax[0,2])
sns.barplot(df_austo_motor, x="Profession", y="No_of_Dependents", ax = ax[0,3])
sns.barplot(df_austo_motor, x="Partner_working", y="Total_salary", ax = ax[1,0])
sns.barplot(df_austo_motor, x="Personal_loan", y="Salary", ax = ax[1,1])
sns.barplot(df_austo_motor, x="Education", y="Salary", ax = ax[1,2])
sns.barplot(df_austo_motor, x="Profession", y="Price", ax = ax[1,3])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Key Questions

# %% [markdown]
# ### 1. Do men tend to prefer SUVs more compared to women?

# %%
sns.countplot(df_austo_motor, x="Make", hue="Gender", palette="dark")
plt.show()

# %% [markdown]
# ### 2. What is the likelihood of a salaried person buying a Sedan?

# %%
sns.countplot(df_austo_motor, x="Make", hue="Profession")
plt.show()

# %% [markdown]
# ### 3. What evidence or data supports Sheldon Cooper's claim that a salaried male is an easier target for a SUV sale over a Sedan sale?

# %%
df_filter = df_austo_motor[(df_austo_motor['Gender'] == "Male") & (df_austo_motor['Personal_loan'] == "No") & (df_austo_motor['House_loan'] == "No")].reset_index(drop=True)
df_filter
# Out:
#      Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0     53   Male   Business        Married  Post Graduate               4.0
# 1     53   Male   Salaried        Married  Post Graduate               3.0
# 2     52   Male   Salaried        Married       Graduate               4.0
# 3     52   Male   Salaried        Married  Post Graduate               4.0
# 4     52   Male   Salaried        Married  Post Graduate               3.0
# ..   ...    ...        ...            ...            ...               ...
# 399   22   Male   Salaried        Married       Graduate               3.0
# 400   22   Male   Salaried        Married       Graduate               3.0
# 401   22   Male   Business        Married       Graduate               3.0
# 402   22   Male   Business        Married       Graduate               4.0
# 403   22   Male   Salaried        Married       Graduate               4.0
#
# ...

# %%
sns.countplot(df_filter, x="Make", hue="Profession", palette="bright")
plt.show()

# %% [markdown]
# ### 4. How does the the amount spent on purchasing automobiles vary by gender?

# %%
# new df_gen has been created to view the average and median price amount spent by each Genders who purchased the automobiles

df_gen = df_austo_motor.groupby('Gender')['Price'].agg(['mean', 'median', 'sum'])
df_gen.columns = ['Average Amount', 'Median Amount', 'Total Amount']
df_gen
# Out:
#         Average Amount  Median Amount  Total Amount
# Gender
# Female    47705.167173        49000.0      15695000
# Male      32416.134185        29000.0      40585000

# %%
df_gen[['Average Amount','Median Amount']].plot(kind='bar', grid="True")
plt.ylabel('Price')

plt.title("Barplot of the average and median amount spent by each Genders who purchased the automobiles")
plt.show()

# %% [markdown]
# ### 5. How much money was spent on purchasing automobiles by individuals who took a personal loan?

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))

sns.barplot(data = df_austo_motor, x = 'Personal_loan', y="Price", palette="dark", ax=ax[0])
sns.boxplot(data=df_austo_motor, x = 'Personal_loan', y= 'Price', ax=ax[1])

ax[0].set_title('Barplot of the amount spent by each individuals w.r.t. personal loan')
ax[1].set_title('Boxplot for the amount(Price) vs Personal_loan')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. How does having a working partner influence the purchase of higher-priced cars?

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))

sns.boxplot(data=df_austo_motor, x = 'Price', y= 'Partner_working', ax=ax[0])
sns.barplot(data = df_austo_motor, x = 'Price', y="Partner_working", palette="colorblind", ax=ax[1])

ax[1].set_title('Barplot of the Price spent by each individuals w.r.t. personal loan')
ax[0].set_title("Boxplot for the Price of the automobiles vs individual's working partner")
plt.tight_layout()
plt.show()

# %%
# df_austo_motor.to_csv('Cleaned_Austo_Motor_Manufacture_data.csv', index=False)

# %% [markdown]
# # Actionable Insights & Recommendations

# %% [markdown]
# ### Actionable insights
#
# 1. Men prefers Sedan and Hatchbacks more than SUV.
# 2. Salaried person are preferred to buy Sedan more than SUV and Hatchbacks.
# 3. Disagreed with the Sheldon Cooper's claim as, the salaried male are more likely to targetted on Sedan and Hatchback car types.
# 4. The Average amount spent by Female to purchase the automobiles is more than Males.
# 5. Individuals who did not take personal loans were more likely to purchase higher-priced cars.
# 6. There is mostly no difference whether their Partner's working or not to purchase the high-priced cars.
#
# ### Recommendations
#
# 1. A campaign must be executed for Male to buy SUV and Female to purchase all 3 types of cars.
# 2. Create a marketing plan and strategies for the Salaried individuals to purchase more SUV and Hatchbacks.
# 3. Regularly analyze the customer data and refine the marketing plans for more profitable business.
# 4. Focus on double-income individuals whose partner's are working to build a solid strategies to purchase maximum high-priced cars.
